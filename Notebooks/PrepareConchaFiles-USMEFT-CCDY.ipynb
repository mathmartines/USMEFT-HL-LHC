# %%
import numpy as np
import json 
import os

# %%
# Folder where the files are stored
folderpath = "/Users/martines/Desktop/PhD/USMEFT-HL-LHC/Data"

# %%
# Load USMEFT predictions
with open(f"{folderpath}/CCDY/USMEFT-CCDY.json") as file_:
    usmeft_ncdy = json.load(file_)

# %%
# Saving each term of the simulations
for term, predictions in usmeft_ncdy.items():
    np.savetxt(
        f"{folderpath}/Concha/CCDY/USMEFT/CCDY-{term}.txt",
        predictions
    )

# %%
with open(f"{folderpath}/CCDY/pseudo_data_SM.json") as file_:
    data = json.load(file_)
    np.savetxt(f"{folderpath}/Concha/CCDY/CCDY-pseudo_data_SM.txt",
           np.transpose([data["data"], data["SM"]])
           )
