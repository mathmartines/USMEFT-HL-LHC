# %%
import numpy as np
import json 
import os

# %%
# Folder where the files are stored
folderpath = "/Users/martines/Desktop/PhD/USMEFT-HL-LHC/Data"

# %%
for filename in os.listdir(f"{folderpath}/NCDY/pseudo_data_Wprime"):
    prefix, _ = filename.split(".")
    print(prefix)
    with open(f"{folderpath}/NCDY/pseudo_data_Wprime/{filename}") as file_:
        data = json.load(file_)
    np.savetxt(f"{folderpath}/Concha/NCDY/pseudo_data_Wprime/{prefix}.txt",
           np.transpose([data["data"], data["SM"]])
           )

# %%
for filename in os.listdir(f"{folderpath}/CCDY/pseudo_data_Wprime"):
    prefix, _ = filename.split(".")
    print(prefix)
    with open(f"{folderpath}/CCDY/pseudo_data_Wprime/{filename}") as file_:
        data = json.load(file_)
    np.savetxt(f"{folderpath}/Concha/CCDY/pseudo_data_Wprime/{prefix}.txt",
           np.transpose([data["data"], data["SM"]])
           )
# Out:
# CCDY-Wprime-beta_15E-02-MXX_6-TeV
# CCDY-Wprime-beta_15E-02-MXX_7-TeV
# CCDY-Wprime-beta_50E-02-MXX_10-TeV
# CCDY-Wprime-beta_35E-02-MXX_7-TeV
# CCDY-Wprime-beta_35E-02-MXX_6-TeV
# CCDY-Wprime-beta_25E-02-MXX_6-TeV
# CCDY-Wprime-beta_25E-02-MXX_7-TeV
# CCDY-Wprime-beta_45E-02-MXX_7-TeV
# CCDY-Wprime-beta_45E-02-MXX_6-TeV
# CCDY-Wprime-beta_55E-02-MXX_10-TeV
# CCDY-Wprime-beta_5E-02-MXX_10-TeV
# CCDY-Wprime-beta_10E-02-MXX_7-TeV
# CCDY-Wprime-beta_10E-02-MXX_6-TeV
# CCDY-Wprime-beta_20E-02-MXX_7-TeV
# CCDY-Wprime-beta_20E-02-MXX_6-TeV
# CCDY-Wprime-beta_10E-02-MXX_10-TeV
# CCDY-Wprime-beta_5E-02-MXX_6-TeV
# CCDY-Wprime-beta_5E-02-MXX_7-TeV
# CCDY-Wprime-beta_30E-02-MXX_6-TeV
# CCDY-Wprime-beta_30E-02-MXX_7-TeV
# CCDY-Wprime-beta_40E-02-MXX_10-TeV
# CCDY-Wprime-beta_50E-02-MXX_7-TeV
# CCDY-Wprime-beta_40E-02-MXX_6-TeV
# CCDY-Wprime-beta_40E-02-MXX_7-TeV
# CCDY-Wprime-beta_15E-02-MXX_10-TeV
# CCDY-Wprime-beta_45E-02-MXX_10-TeV
# CCDY-Wprime-beta_75E-02-MXX_10-TeV
# CCDY-Wprime-beta_25E-02-MXX_10-TeV
# CCDY-Wprime-beta_10E-02-MXX_9-TeV
# CCDY-Wprime-beta_10E-02-MXX_8-TeV
# CCDY-Wprime-beta_20E-02-MXX_9-TeV
# CCDY-Wprime-beta_20E-02-MXX_8-TeV
# CCDY-Wprime-beta_5E-02-MXX_8-TeV
# CCDY-Wprime-beta_5E-02-MXX_9-TeV
# CCDY-Wprime-beta_30E-02-MXX_8-TeV
# CCDY-Wprime-beta_30E-02-MXX_9-TeV
# CCDY-Wprime-beta_70E-02-MXX_10-TeV
# CCDY-Wprime-beta_35E-02-MXX_5-TeV
# CCDY-Wprime-beta_50E-02-MXX_9-TeV
# CCDY-Wprime-beta_50E-02-MXX_8-TeV
# CCDY-Wprime-beta_40E-02-MXX_8-TeV
# CCDY-Wprime-beta_40E-02-MXX_9-TeV
# CCDY-Wprime-beta_25E-02-MXX_5-TeV
# CCDY-Wprime-beta_25E-02-MXX_4-TeV
# CCDY-Wprime-beta_20E-02-MXX_10-TeV
# CCDY-Wprime-beta_15E-02-MXX_5-TeV
# CCDY-Wprime-beta_15E-02-MXX_4-TeV
# CCDY-Wprime-beta_60E-02-MXX_9-TeV
# CCDY-Wprime-beta_60E-02-MXX_8-TeV
# CCDY-Wprime-beta_15E-02-MXX_8-TeV
# CCDY-Wprime-beta_15E-02-MXX_9-TeV
# CCDY-Wprime-beta_35E-02-MXX_9-TeV
# CCDY-Wprime-beta_35E-02-MXX_8-TeV
# CCDY-Wprime-beta_65E-02-MXX_10-TeV
# CCDY-Wprime-beta_25E-02-MXX_8-TeV
# CCDY-Wprime-beta_25E-02-MXX_9-TeV
# CCDY-Wprime-beta_35E-02-MXX_10-TeV
# CCDY-Wprime-beta_20E-02-MXX_4-TeV
# CCDY-Wprime-beta_20E-02-MXX_5-TeV
# CCDY-Wprime-beta_45E-02-MXX_9-TeV
# CCDY-Wprime-beta_45E-02-MXX_8-TeV
# CCDY-Wprime-beta_55E-02-MXX_8-TeV
# CCDY-Wprime-beta_55E-02-MXX_9-TeV
# CCDY-Wprime-beta_5E-02-MXX_5-TeV
# CCDY-Wprime-beta_5E-02-MXX_4-TeV
# CCDY-Wprime-beta_30E-02-MXX_5-TeV
# CCDY-Wprime-beta_30E-02-MXX_4-TeV
# CCDY-Wprime-beta_60E-02-MXX_10-TeV
# CCDY-Wprime-beta_65E-02-MXX_9-TeV
# CCDY-Wprime-beta_30E-02-MXX_10-TeV
# CCDY-Wprime-beta_10E-02-MXX_4-TeV
# CCDY-Wprime-beta_10E-02-MXX_5-TeV
